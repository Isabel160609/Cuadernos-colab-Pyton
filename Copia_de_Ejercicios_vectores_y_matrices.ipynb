# %% [markdown]
# <a href="https://colab.research.google.com/github/Isabel160609/Cuadernos-colab-Pyton/blob/main/Copia_de_Ejercicios_vectores_y_matrices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. El Registro de Temperatura (Lista)**
# Tienes una lista de temperaturas de la semana. Suma una "corrección" de 2 grados a cada una.
#
# Dato: temps = [18, 20, 22]
#
# Reto: Crea una nueva lista donde cada valor sea v + 2.

# %%
import numpy as np
temps = [18, 20, 22]
temps = np.array(temps)
temps_corregido = temps + 2
print(temps_corregido)
# Out:
# [20 22 24]

# %% [markdown]
# **2. Coordenadas Inmutables (Tupla)**
# Representa un punto en un mapa 2D.
#
# Dato: punto = (10, 25)
#
# Reto: Intenta cambiar el 10 por un 15. Observa el error que lanza Python (esto te enseñará por qué las tuplas son para datos que no deben cambiar).

# %%
punto = (10, 25)
punto[0] = 15
print(punto)

punto2 = (15, 25)
print(punto2)

punto3 =(punto[0]+5, punto[1])
print(punto3)

punto4 = (15, punto[1])
print(punto4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_858/2444730670.py in <cell line: 0>()
#       1 punto = (10, 25)
# ----> 2 punto[0] = 15
#       3 print(punto)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **3. El Carrito de Compras (Lista)**
# Tienes los precios de tres productos.
#
# Dato: precios = [10.5, 5.0, 2.99]
#
# Reto: Usa la función sum(precios) para obtener el total. Luego, usa len(precios) para saber cuántos productos hay.

# %%
precios = [10.5, 5.0, 2.99]
total = sum(precios)
cantidad = len(precios)
print (f"la suma de los precios es: {total:.2f}")
print(f"la cantidad de precios es: {cantidad:.2f}")
print(f"la media de los precios es: {total/cantidad:.2f}")
# Out:
# la suma de los precios es: 18.5
# la cantidad de precios es: 3.0
# la media de los precios es: 6.16

# %% [markdown]
# **4. El Sensor de Presión (Tupla)**
# Un sensor devuelve tres valores de presión.
#
# Dato: lectura = (1013, 1012, 1015)
#
# Reto: Accede al segundo elemento (índice 1) y guárdalo en una variable llamada presion_mediodia.

# %%
lectura = (1013, 1012, 1015)
presion_mediodia = lectura[1]
print(presion_mediodia)
# Out:
# 1012

# %% [markdown]
# **5. Combinando Datos (Zip + Listas)**
# Tienes nombres de alumnos y sus notas.
#
# Datos: alumnos = ["Ana", "Luis"], notas = [9, 8]
#
# Reto: Usa list(zip(alumnos, notas)) para crear una lista de parejas.

# %%
alumnos = ["Ana", "Luis"]
notas = [9, 8]
lista_alumnos = list(zip(alumnos, notas))
print(lista_alumnos)
# Out:
# [('Ana', 9), ('Luis', 8)]

# %% [markdown]
# **6. El Tablero de Michi/Gato (Lista de Listas)**
# Crea un tablero de 3x3 lleno de ceros.
#
# Código: tablero = [[0, 0, 0], [0, 0, 0], [0, 0, 0]]
#
# Reto: Cambia el centro del tablero a 1 (jugador X) usando tablero[1][1] = 1.

# %%
tablero = [[0, 0, 0], [0, 0, 0], [0, 0, 0]]
tablero[1][1] = 1
print(tablero)
# Out:
# [[0, 0, 0], [0, 1, 0], [0, 0, 0]]

# %% [markdown]
# **7. Matriz de Configuración (Tupla Anidada)**
# Imagina una matriz de 2x2 que guarda límites de brillo (min, max).
#
# Dato: limites = ((0, 100), (50, 150))
#
# Reto: Imprime el valor 150 accediendo a la posición correcta [1][1].

# %%
limites = ((0, 100), (50, 150))
print(limites[1][1])
# Out:
# 150

# %% [markdown]
# **8. Suma de Filas (Lista de Listas)**
# Tienes una matriz donde cada fila es el gasto diario de una persona en 2 días.
#
# Dato: gastos = [[10, 5], [20, 30]]
#
# Reto: Usa un bucle for para imprimir la suma de cada fila.

# %%
gastos = [[10, 5], [20, 30]]
for fila in gastos:
    suma = sum(fila)
    print(suma)
# Out:
# 15
# 50

# %% [markdown]
# **9. Transposición Básica (Lista de Tuplas)**
# A veces los datos vienen como una lista de filas, donde cada fila es una tupla.
#
# Dato: data = [(1, 2), (3, 4)]
#
# Reto: Crea una nueva lista que contenga solo el primer elemento de cada tupla: [1, 3].

# %%
data = [(1, 2), (3, 4)]
primeros = [tupla[0] for tupla in data]
print(primeros)
# Out:
# [1, 3]

# %% [markdown]
# **10. El Filtro de Imagen (Lista de Listas)**
# Representa una "imagen" de 2x2 píxeles (escala de grises).
#
# Dato: pixeles = [[255, 0], [128, 64]]
#
# Reto: Multiplica cada valor por 0.5 para "oscurecer" la imagen a la mitad.

# %%
import numpy as np
pixeles = [[255, 0], [128, 64]]
pixeles = np.array(pixeles)
oscurecido = pixeles * 0.5
print(oscurecido)
# Out:
# [[127.5   0. ]
#  [ 64.   32. ]]
